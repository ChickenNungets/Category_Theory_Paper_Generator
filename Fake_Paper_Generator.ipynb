# %% [markdown]
# <a href="https://colab.research.google.com/github/ChickenNungets/Category_Theory_Paper_Generator/blob/main/Fake_Paper_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-tuning a Code LLM on TeX Research Papers
#
# Big thanks to [Maria Khalusova](https://github.com/MKhalusova). Parts of this code are adapted from her work.
#
#
# ## Dataset
#
# The dataset used here is a collection of about 900 TeX files, gathered from recent category theory math publications using the Arxiv API.
#
#
# ## Model
#
# I fine tune [`bigcode/starcoderbase-1b`](https://huggingface.co/bigcode/starcoderbase-1b), which is a 1B parameter model trained on 80+ programming languages.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install -q transformers datasets peft bitsandbytes flash-attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 34.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
#   Building wheel for flash-attn (setup.py) ... done

# %%
MODEL="bigcode/starcoderbase-1b" # Model checkpoint on the Hugging Face Hub
#DATASET="smangrul/hf-stack-v1"   # Dataset on the Hugging Face Hub
DATA_COLUMN="text"            # Column name containing the code content

SEQ_LENGTH=2048                  # Sequence length

# Training arguments
MAX_STEPS=2000                   # max_steps
BATCH_SIZE=16                    # batch_size
GR_ACC_STEPS=1                   # gradient_accumulation_steps
LR=5e-4                          # learning_rate
LR_SCHEDULER_TYPE="cosine"       # lr_scheduler_type
WEIGHT_DECAY=0.01                # weight_decay
NUM_WARMUP_STEPS=30              # num_warmup_steps
EVAL_FREQ=100                    # eval_freq
SAVE_FREQ=100                    # save_freq
LOG_FREQ=25                      # log_freq
OUTPUT_DIR="peft-starcoder-lora-a100" # output_dir
BF16=True                        # bf16
FP16=False                       # no_fp16

# FIM trasformations arguments
FIM_RATE=0.5                     # fim_rate
FIM_SPM_RATE=0.5                 # fim_spm_rate

# LORA
LORA_R=8                         # lora_r
LORA_ALPHA=32                    # lora_alpha
LORA_DROPOUT=0.0                 # lora_dropout
LORA_TARGET_MODULES="c_proj,c_attn,q_attn,c_fc,c_proj"    # lora_target_modules

# bitsandbytes config
USE_NESTED_QUANT=True            # use_nested_quant
BNB_4BIT_COMPUTE_DTYPE="bfloat16"# bnb_4bit_compute_dtype

SEED=0

# %%
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    Trainer,
    TrainingArguments,
    logging,
    set_seed,
    BitsAndBytesConfig,
)

set_seed(SEED)

# %% [markdown]
# ## Prepare the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

data_dir = '/content/drive/MyDrive/extracted'  # Adjust the path if necessary
print(f"Number of TeX files: {len([name for name in os.listdir(data_dir) if name.endswith('.tex')])}")
# Out:
# Number of TeX files: 907

# %%
import glob

# Get list of .tex files
file_list = glob.glob(os.path.join(data_dir, '**/*.tex'), recursive=True)

# Read the contents of each file into a list
texts = []
for file_path in file_list:
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as infile:
        content = infile.read()
        texts.append(content)

# Create a dataset from the list of texts
from datasets import Dataset

dataset = Dataset.from_dict({'text': texts})

# %%
from datasets import load_dataset
import torch
from tqdm import tqdm




valid_data = dataset.take(100)
train_data = dataset.skip(100)
train_data = train_data.shuffle(seed=SEED)

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)

def chars_token_ratio(dataset, tokenizer, data_column, nb_examples=200):
    """
    Estimate the average number of characters per token in the dataset.
    """

    total_characters, total_tokens = 0, 0
    for _, example in tqdm(zip(range(nb_examples), iter(dataset)), total=nb_examples):
        total_characters += len(example[data_column])
        total_tokens += len(tokenizer(example[data_column]).tokens())

    return total_characters / total_tokens


chars_per_token = chars_token_ratio(train_data, tokenizer, DATA_COLUMN)
print(f"The character to token ratio of the dataset is: {chars_per_token:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/442k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/532 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 100%|██████████| 200/200 [00:23<00:00,  8.44it/s]
# The character to token ratio of the dataset is: 2.69

# %% [markdown]
# ## FIM transformations

# %%
import functools
import numpy as np


# Helper function to get token ids of the special tokens for prefix, suffix and middle for FIM transformations.
@functools.lru_cache(maxsize=None)
def get_fim_token_ids(tokenizer):
    try:
        FIM_PREFIX, FIM_MIDDLE, FIM_SUFFIX, FIM_PAD = tokenizer.special_tokens_map["additional_special_tokens"][1:5]
        suffix_tok_id, prefix_tok_id, middle_tok_id, pad_tok_id = (
            tokenizer.vocab[tok] for tok in [FIM_SUFFIX, FIM_PREFIX, FIM_MIDDLE, FIM_PAD]
        )
    except KeyError:
        suffix_tok_id, prefix_tok_id, middle_tok_id, pad_tok_id = None, None, None, None
    return suffix_tok_id, prefix_tok_id, middle_tok_id, pad_tok_id


## Adapted from https://github.com/bigcode-project/Megatron-LM/blob/6c4bf908df8fd86b4977f54bf5b8bd4b521003d1/megatron/data/gpt_dataset.py
def permute(
    sample,
    np_rng,
    suffix_tok_id,
    prefix_tok_id,
    middle_tok_id,
    pad_tok_id,
    fim_rate=0.5,
    fim_spm_rate=0.5,
    truncate_or_pad=False,
):
    """
    Take in a sample (list of tokens) and perform a FIM transformation on it with a probability of fim_rate, using two FIM modes:
    PSM and SPM (with a probability of fim_spm_rate).
    """

    # The if condition will trigger with the probability of fim_rate
    # This means FIM transformations will apply to samples with a probability of fim_rate
    if np_rng.binomial(1, fim_rate):

        # Split the sample into prefix, middle, and suffix, based on randomly generated indices stored in the boundaries list.
        boundaries = list(np_rng.randint(low=0, high=len(sample) + 1, size=2))
        boundaries.sort()

        prefix = np.array(sample[: boundaries[0]], dtype=np.int64)
        middle = np.array(sample[boundaries[0] : boundaries[1]], dtype=np.int64)
        suffix = np.array(sample[boundaries[1] :], dtype=np.int64)

        if truncate_or_pad:
            # calculate the new total length of the sample, taking into account tokens indicating prefix, middle, and suffix
            new_length = suffix.shape[0] + prefix.shape[0] + middle.shape[0] + 3
            diff = new_length - len(sample)

            # trancate or pad if there's a difference in length between the new length and the original
            if diff > 0:
                if suffix.shape[0] <= diff:
                    return sample, np_rng
                suffix = suffix[: suffix.shape[0] - diff]
            elif diff < 0:
                suffix = np.concatenate([suffix, np.full((-1 * diff), pad_tok_id)])

        # With the probability of fim_spm_rateapply SPM variant of FIM transformations
        # SPM: suffix, prefix, middle
        if np_rng.binomial(1, fim_spm_rate):
            new_sample = np.concatenate(
                [
                    [prefix_tok_id, suffix_tok_id],
                    suffix,
                    [middle_tok_id],
                    prefix,
                    middle,
                ]
            )
        # Otherwise, apply the PSM variant of FIM transformations
        # PSM: prefix, suffix, middle
        else:

            new_sample = np.concatenate(
                [
                    [prefix_tok_id],
                    prefix,
                    [suffix_tok_id],
                    suffix,
                    [middle_tok_id],
                    middle,
                ]
            )
    else:
        # don't apply FIM transformations
        new_sample = sample

    return list(new_sample), np_rng

# %% [markdown]
# ## Make dataset iterable and constant length

# %%
from torch.utils.data import IterableDataset
from torch.utils.data.dataloader import DataLoader
import random

# Create an Iterable dataset that returns constant-length chunks of tokens from a stream of text files.

class ConstantLengthDataset(IterableDataset):
    """
    Iterable dataset that returns constant length chunks of tokens from stream of text files.
        Args:
            tokenizer (Tokenizer): The processor used for proccessing the data.
            dataset (dataset.Dataset): Dataset with text files.
            infinite (bool): If True the iterator is reset after dataset reaches end else stops.
            seq_length (int): Length of token sequences to return.
            num_of_sequences (int): Number of token sequences to keep in buffer.
            chars_per_token (int): Number of characters per token used to estimate number of tokens in text buffer.
            fim_rate (float): Rate (0.0 to 1.0) that sample will be permuted with FIM.
            fim_spm_rate (float): Rate (0.0 to 1.0) of FIM permuations that will use SPM.
            seed (int): Seed for random number generator.
    """

    def __init__(
        self,
        tokenizer,
        dataset,
        infinite=False,
        seq_length=1024,
        num_of_sequences=1024,
        chars_per_token=3.6,
        content_field="content",
        fim_rate=0.5,
        fim_spm_rate=0.5,
        seed=0,
    ):
        self.tokenizer = tokenizer
        self.concat_token_id = tokenizer.eos_token_id
        self.dataset = dataset
        self.seq_length = seq_length
        self.infinite = infinite
        self.current_size = 0
        self.max_buffer_size = seq_length * chars_per_token * num_of_sequences
        self.content_field = content_field
        self.fim_rate = fim_rate
        self.fim_spm_rate = fim_spm_rate
        self.seed = seed

        (
            self.suffix_tok_id,
            self.prefix_tok_id,
            self.middle_tok_id,
            self.pad_tok_id,
        ) = get_fim_token_ids(self.tokenizer)
        if not self.suffix_tok_id and self.fim_rate > 0:
            print("FIM is not supported by tokenizer, disabling FIM")
            self.fim_rate = 0

    def __iter__(self):
        iterator = iter(self.dataset)
        more_examples = True
        np_rng = np.random.RandomState(seed=self.seed)
        while more_examples:
            buffer, buffer_len = [], 0
            while True:
                if buffer_len >= self.max_buffer_size:
                    break
                try:
                    buffer.append(next(iterator)[self.content_field])
                    buffer_len += len(buffer[-1])
                except StopIteration:
                    if self.infinite:
                        iterator = iter(self.dataset)
                    else:
                        more_examples = False
                        break
            tokenized_inputs = self.tokenizer(buffer, truncation=False)["input_ids"]
            all_token_ids = []

            for tokenized_input in tokenized_inputs:
                # optionally do FIM permutations
                if self.fim_rate > 0:
                    tokenized_input, np_rng = permute(
                        tokenized_input,
                        np_rng,
                        self.suffix_tok_id,
                        self.prefix_tok_id,
                        self.middle_tok_id,
                        self.pad_tok_id,
                        fim_rate=self.fim_rate,
                        fim_spm_rate=self.fim_spm_rate,
                        truncate_or_pad=False,
                    )

                all_token_ids.extend(tokenized_input + [self.concat_token_id])
            examples = []
            for i in range(0, len(all_token_ids), self.seq_length):
                input_ids = all_token_ids[i : i + self.seq_length]
                if len(input_ids) == self.seq_length:
                    examples.append(input_ids)
            random.shuffle(examples)
            for example in examples:
                self.current_size += 1
                yield {
                    "input_ids": torch.LongTensor(example),
                    "labels": torch.LongTensor(example),
                }


train_dataset = ConstantLengthDataset(
        tokenizer,
        train_data,
        infinite=True,
        seq_length=SEQ_LENGTH,
        chars_per_token=chars_per_token,
        content_field=DATA_COLUMN,
        fim_rate=FIM_RATE,
        fim_spm_rate=FIM_SPM_RATE,
        seed=SEED,
)
eval_dataset = ConstantLengthDataset(
        tokenizer,
        valid_data,
        infinite=False,
        seq_length=SEQ_LENGTH,
        chars_per_token=chars_per_token,
        content_field=DATA_COLUMN,
        fim_rate=FIM_RATE,
        fim_spm_rate=FIM_SPM_RATE,
        seed=SEED,
)

# %% [markdown]
# ## Prepare the model

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from peft.tuners.lora import LoraLayer

load_in_8bit = False

# 4-bit quantization
compute_dtype = getattr(torch, BNB_4BIT_COMPUTE_DTYPE)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=USE_NESTED_QUANT,
)

device_map = {"": 0}

model = AutoModelForCausalLM.from_pretrained(
        MODEL,
        load_in_8bit=load_in_8bit,
        quantization_config=bnb_config,
        device_map=device_map,
        use_cache=False,  # We will be using gradient checkpointing
        trust_remote_code=True,
        use_flash_attention_2=True,
)
# Out:
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# The model was loaded with use_flash_attention_2=True, which is deprecated and may be removed in a future release. Please use `attn_implementation="flash_attention_2"` instead.
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
model = prepare_model_for_kbit_training(model)

# %%
# Set up lora
peft_config = LoraConfig(
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    r=LORA_R,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=LORA_TARGET_MODULES.split(","),
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# trainable params: 5,554,176 || all params: 1,142,761,472 || trainable%: 0.4860

# %% [markdown]
# ## Train the model

# %%
train_data.start_iteration = 0


training_args = TrainingArguments(
    output_dir=f"Maxva/mathpaper",
    dataloader_drop_last=True,
    evaluation_strategy="steps",
    save_strategy="steps",
    max_steps=MAX_STEPS,
    eval_steps=EVAL_FREQ,
    save_steps=SAVE_FREQ,
    logging_steps=LOG_FREQ,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    learning_rate=LR,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    warmup_steps=NUM_WARMUP_STEPS,
    gradient_accumulation_steps=GR_ACC_STEPS,
    gradient_checkpointing=True,
    fp16=FP16,
    bf16=BF16,
    weight_decay=WEIGHT_DECAY,
    push_to_hub=True,
    include_tokens_per_second=True,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(
    model=model, args=training_args, train_dataset=train_dataset, eval_dataset=eval_dataset
)
trainer.init_hf_repo()
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
print("Training...")
trainer.train()
# Out:
# Training...
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2000/2000 2:04:40, Epoch 1/9223372036854775807]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.383100</td>
#       <td>1.432553</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.247500</td>
#       <td>1.414930</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.293700</td>
#       <td>1.390325</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.318700</td>
#       <td>1.372281</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.418500</td>
#       <td>1.357698</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.381600</td>
#       <td>1.347546</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.324000</td>
#       <td>1.346695</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.345600</td>
#       <td>1.334711</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.290600</td>
#       <td>1.335997</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.291600</td>
#       <td>1.331543</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.385100</td>
#       <td>1.323239</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.182700</td>
#       <td>1.319275</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.270400</td>
#       <td>1.318023</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.249500</td>
#       <td>1.310392</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.298600</td>
#       <td>1.305930</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.375900</td>
#       <td>1.300511</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>1.277500</td>
#       <td>1.298345</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>1.264800</td>
#       <td>1.296919</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>1.224700</td>
#       <td>1.296139</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.215200</td>
#       <td>1.295875</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# TrainOutput(global_step=2000, training_loss=1.3307072343826294, metrics={'train_runtime': 7486.7975, 'train_samples_per_second': 4.274, 'train_steps_per_second': 0.267, 'train_tokens_per_second': 8753.543, 'total_flos': 4.0317260660736e+17, 'train_loss': 1.3307072343826294, 'epoch': 1.0})

# %%
trainer.push_to_hub()
# Out:
# CommitInfo(commit_url='https://huggingface.co/Maxva/mathpaper/commit/7838ffc71e85d3e64583fdcc57cef5880119b7ae', commit_message='End of training', commit_description='', oid='7838ffc71e85d3e64583fdcc57cef5880119b7ae', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Merge and Inference

# %%
from peft import PeftModel
import torch

# load the original model first
tokenizer = AutoTokenizer.from_pretrained(MODEL, trust_remote_code=True)
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL,
    quantization_config=None,
    device_map=None,
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
).cuda()

# merge fine-tuned weights with the base model
peft_model_id = f"Maxva/mathpaper"
model = PeftModel.from_pretrained(base_model, peft_model_id)
model.merge_and_unload()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# GPTBigCodeForCausalLM(
#   (transformer): GPTBigCodeModel(
#     (wte): Embedding(49152, 2048)
#     (wpe): Embedding(8192, 2048)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPTBigCodeBlock(
#         (ln_1): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTBigCodeSdpaAttention(
#           (c_attn): Linear(in_features=2048, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTBigCodeMLP(
#           (c_fc): Linear(in_features=2048, out_features=8192, bias=True)
#           (c_proj): Linear(in_features=8192, out_features=2048, bias=True)
#           (act): PytorchGELUTanh()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=2048, out_features=49152, bias=False)
# )

# %%
def get_code_completion(prefix, suffix, steps=35):
    #text = f"""<fim_prefix>{prefix}<fim_suffix>{suffix}<fim_middle>"""
    text = prefix
    for i in range(steps):
      if i == steps - 1:
        text = f"""<fim_prefix>{text}<fim_suffix>{suffix}"""
      model.eval()
      outputs = model.generate(
          input_ids=tokenizer(text, return_tensors="pt").input_ids.cuda(),
          max_new_tokens=256,
          temperature=0.9,
          top_k=70,
          top_p=0.92,
          do_sample=True,
          repetition_penalty=1.1,
          #pad_tok_id = tokenizer.eos_token_id
      )
      text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

    return text

# %% [markdown]
# ## Example!

# %%
prefix = r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{On The Monoindal Endofunctor In Sparse Categories}
\author{Max Vazquez}
\maketitle

"""
suffix =r"""
\end{document}
"""

print(get_code_completion(prefix, suffix))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# \documentclass[a4paper,reqno,oneside]{article}
# \pdfoutput=1
# \include{mathcommands.extratex}
# \begin{document}
# \title{On The Monoindal Endofunctor In Sparse Categories}
# \author{Max Vazquez}
# \maketitle
#
#  \begin{abstract}
#      In this paper we show how the monoinductor endofunctor is defined on a (sparse) category, and prove its naturality in a context of a certain combinatorial morphism. More precisely, we show that the endofunctor $\id_{\cat{S}}$ becomes natural when applied to maps of sets $F: \{0, 1\} \times \mathcal{C} \to \mathcal{D}$ whose underlying set is an object in the endofunctor category of a subset $X$ and such that $X/F$ is compact. This can be further extended to a general morphism of categories.
#   \end{abstract}
#
# \section*{Introduction}
# The ``monoidal product'' of two (or more) sets is the one defined by taking their concatenation in the usual sense:
# \[
#     A \otimes B = \{a, b \in A \cup B\}.
# \]
# In more technical terms, if $A \xrightarrow{f} B$ and $C \xrightarrow{g} D$, then $A \oplus C$ is the union of elements $a \in A$ together with $g(c)$ for each $c \in C$.
# One way to think about such products are as ``dividing the set into pieces'', i.e.\ as creating copies of some piece in the original set. It is not difficult to see that dividing a list of objects in a set into different pieces is a simple and efficient operation. However, even if a list of such pieces would divide the set up into pieces, it might not be easily possible to know what exactly the elements from each piece should be merged. For example, let us suppose there was a string diagram like this one for $n \geq 2$:
# \[
# \tikzfig{diagram}
# \]
# It seems natural to expect the ``product'' of two sets to divide the diagram into the corresponding pieces according to the sum of the elements appearing in any given piece. The ``monoidal product'' of two sets is the one obtained by taking their concatenation, so in this case we obtain a list of lists where each list represents a distinct piece of the diagram. Let us now define a monoid on the diagram in the above example as follows:
# \[
#     D^* = \{0, 1, \cdots, n-2, \ldots, n-2 \otimes n-1\}, \quad F^* = \{0, 1, \cdots, n\},
# \]
# i.e.\ $\mathbf{D}^*$ is the singleton list and $\mathbf{F}^*$ is the empty list. Since they are lists, the monoid multiplication and addition are just as straightforward as adding a couple of lists elementwise. Finally, it turns out that this definition fits entirely within our intuition: if two lists $(A, \beta_0, \ldots, \beta_k)$ and $(B, \gamma_0, \ldots, \gamma_{k+1})$ are combined together in an arbitrary order such that the sum of the element $(B \otimes A) \beta_0 + \ldots + (B \otimes A) \beta_k + (A \otimes B) \gamma_0 + \ldots + (A \otimes B) \gamma_{k+1}$, then these two lists will be combined into the same list with no extra copy of each element appearing in one but several times in the other.
#
# As a result of combining those lists, we obtain a new list where each list represents a distinct piece of the diagram. Indeed, whenever $A \oplus B$ contains the elements $\beta_j$ of $A$ together with $\gamma_{k}$ of $B$ after having been combined along with its other copies of $\beta_j$ of $A$, the two lists produced will contain the same data without making any copies. This happens in both cases: we can add the element of $\beta_j$ (that does not appear anywhere in $A$) to either the list of copies of $\beta_j$ or the list of copies of $\beta_{j-1}$. Combining those lists, we obtain a list where each list represents a distinct piece of the diagram, that is, all the pieces will appear together again in the correct places. We say that such a list has a \textit{composition property}: for example, every piece of the diagram will eventually be combined into a new piece.
#
# One could also think of $\mathbf{D}^*$ as being the empty list or $\mathbf{F}^*$ as being the singleton list; however, as soon as we consider their composition property, we find ourselves wondering what each piece of the diagram should look like if we combine them into new pieces. In this article we want to give an alternative approach to understanding such composite objects, and we provide this idea as a counterexample for the monoinductive formula.
#
# If you are interested in learning more about the mathematics behind such a composite concept, we suggest reading \cite{Brown94}.  As a complement, we invite you to read \cite{Garner2008}.
#
# \subsection*{Notation}
# Let $P(n)$ be the index set containing all pairs of natural numbers $p < q$ such that $p + q$ equals $n$. The monoid $\mathbf{D}^*$ is denoted $\mathbf{D}(P)$. Similarly, let $P(n)$ be the index set containing all pairs of natural numbers $p < q$ such that $q = p + n$. The monoid $\mathbf{F}^*$ is denoted $\mathbf{F}(P)$. These indices will only be used very often throughout this paper, so we will avoid using them to clarify notation.
#
# \section{The Monoinductive Formula}
# We want to develop a well-behaved category theory by developing a functor between categories in which each monoid is acted upon individually.  We do this by introducing the notion of a \textit{morphism of monoids}, which will be described below.
#
# \begin{definition}
#     Given a pair of index sets $P(n)$ and $Q(m)$, a morphism $\mathcal{C}(P, Q): \mathcal{C}(P) \to \mathcal{C}(Q)$ is called \textit{homotopy} \textit{$P$-natural} if, for each object $a \in P$, the map $\mathcal{C}(P, Q)(a, a) : \mathcal{C}(P, Q)(a, a) \to \mathcal{C}(Q)(a, a)$ of categories induces a natural transformation $\mathcal{C}(P, Q)^* : \mathcal{C}(P \times Q) \to \mathcal{C}(P \times Q)$ of categories, such that $\mathcal{C}(Q)^*\mathcal{C}(P, Q)(a, a) = \mathcal{C}(P)^*(a)$.
# \end{definition}
#
# Now, if we are given two homotopy $P$-natural transformations of categories $\mathcal{C}(P) \to \mathcal{C}(Q)$ and $\mathcal{C}(Q) \to \mathcal{C}(P)$, then we can compose them in the following way:
# \[
# \begin{tikzcd}
#     P \times Q & \times & P \\
#     & \mathcal{C}(P) && \mathcal{C}(Q)
# \end{tikzcd}
# \]
# where the two vertical arrows are homotopy natural transformations of categories. Then we have a natural transformation
# \[
# \begin{tikzcd}
#     P \times Q & \times & P \times Q \\
#     & \mathcal{C}(P \times Q) && \mathcal{C}(P \times Q)
# \end{tikzcd}
# \]
# which is homotopy $P$-natural.
#
# We also introduce another kind of morphism of monoids, called \textit{composition morphism}.
#
# \begin{definition}
# Given a pair of index sets $P(n)$ and $Q(m)$, a morphism $\mathcal{C}(P, Q)_*: \mathcal{C}(P) \times \mathcal{C}(Q) \to \mathcal{C}(P \times Q)$ is called \textit{composition} \textit{$(P, Q)$-natural} if, for each $p,q \in P(n)$, the following commutative diagram in $\mathcal{C}(P)$ is a pullback square:
# \[
# \begin{tikzcd}
#     P^*_q \times_P P \ar[r] \ar[d] & P^*_q \ar[l] \\
#     P \ar[ur] \ar[rd] \ar[r]& P
# \end{tikzcd}
# \]
# and similarly in $\mathcal{C}(Q)$:
# \[
# \begin{tikzcd}
#     Q^*_p \times_Q Q \ar[r] \ar[d] & Q^*_p \ar[l] \\
#     Q \ar[ur] \ar[rd] \ar[r]& Q
# \end{tikzcd}
# \]
# Then this morphism of monoids satisfies the monoidal laws: given two $n$-sorted lists $(p_0,\dots,p_n)\in P(n)$ and $(q_0,\dots,q_m)\in Q(m)$ with $p_i \leq q_i$ for each $i$, then $\mathcal{C}(P, Q)^*(p_0,\dots,p_n,q_0,\dots,q_m)$ and $\mathcal{C}(Q, P)^*(p_0,\dots,p_n,q_0,\dots,q_m)$ are equal if and only if the list corresponding to the composition of these lists corresponds to the composition of these lists.
# \end{definition}
#
# \begin{definition}
#     If $\mathcal{C}$ is a category with a monoid structure, we say that it is \textit{closed under compositions of monoids} if, given two $n$-sorted lists $(p_0,\dots,p_n)\in P(n)$ and $(q_0,\dots,q_m)\in Q(m)$ with $p_i \leq q_i$ for each $i$, then there is a unique $p'\in P(n)$ such that $\mathcal{C}(P, Q)^*(p',p_0,\dots,p_n,q_0,\dots,q_m) \neq 0$. Such a closed set of monoids is called the \textit{domain} of the monoid structure on $\mathcal{C}$.
# \end{definition}
#
# Finally, we introduce another kind of morphism of monoids that is called \textit{unit morphism}:
#
# \begin{definition}
#     If $\mathcal{C}$ is a category with a monoid structure, we say that it is \textit{closed under units of monoids} if, given a $n$-sorted list $(p_0,\dots,p_n)\in P(n)$, then there is a unique $p'\in P(n)$ such that $\mathcal{C}^{*}\mathcal{C}(P, P)^*(p',p_0,\dots,p_n,0) \neq 0$. Such a closed set of monoids is called the \textit{codomain} of the monoid structure on $\mathcal{C}$.
# \end{definition}
#
# Now let us state the main properties of a monoid.
#
# \begin{proposition}[{\cite[Proposition~1.5]{Garner2008}}]\label{prop:monoid}
#     If $\mathcal{C}$ is a category with a monoid structure, then it satisfies the following properties:
#     \begin{itemize}
#         \item[$\bullet$] The monoid structure on $\mathcal{C}$ is finite-dimensional, in particular:
#         \begin{enumerate}
#             \item[(a)] A monoid $X$ is either zero or a product of itself-complemented finite-dimensional subsets of $X$, so that the coproduct of each subset is a finite-dimensional product of the coproducts of its elements.
#             \item[(b)] Any two disjoint subsets of $X$ form a monoid.
#         \end{enumerate}
#         \item[$\bullet$] For any set $Y$ and any nonzero $n \geq 0$, the composition morphism
#         \[
#         X \times Y \to \mathcal{C}(X \times Y, X)
#         \]
#         is a monoid morphism, i.e.,
#         \[
#             (\mathcal{C}(X \times Y, X))(a,b) = X(a,b) \times Y(a,b).
#         \]
#         \item[$\bullet$] For any set $Y$ and any nonzero $m \geq 0$, the unit morphism
#         \[
#         X \times 0 \to \mathcal{C}(X \times 0, X)
#         \]
#         is a monoid morphism, i.e.,
#         \[
#             (\mathcal{C}(X \times 0, X))(a,0) = X(a,0).
#         \]
#         \item[$\bullet$] The free monoid is isomorphic to the product of the finite-dimensional subsets of $\{0,1\} \times \mathcal{C}(X, X)$ satisfying the universal property: for each $p,q \in P(n)$, $\mathcal{C}^{*}\mathcal{C}(P(n), P(n))(p,q) = 0$ if and only if $p + q = m$.
#     \end{itemize}
# \end{proposition}
#
# For the propositions $\ref{prop:monoid}$ and $\ref{prop:free},$ we will use the notation of \textit{compactness}:
#
# \begin{definition}
#     Given an object $x \in \mathcal{C}$, we say that $x$ is \textit{compact} if, for each nonzero $p \in P(n)$, $x(p) \subseteq x(p + n)$.
#     A monoid is \textit{compact} if it satisfies property $\ref{prop:monoid}$ or is equivalently compact for all $x \in \mathcal{C}$, i.e.\ $x(0) \subseteq x(n)$ for all $n \geq 1$. Indeed, it is easy to see that the condition (b) implies that the unit morphism is monoid homomorphism and therefore there is a unique nonzero $p' \in P(n)$ such that $x(p') \subseteq x(p)$.
# \end{definition}
#
# Let us now talk about why it is possible to define this notion. Before, we wanted to express the following fact: given a family of $m$ nonzero indices $P(m)$ and some $n$-sorted list $p_0,\dots,p_n \in P(n)$, the map $\{p_0,\dots,p_n\} \to \{0,1,\ldots,m\}$ is continuous. This means that it sends $x \mapsto x(0) \subseteq x(n)$ whenever $x(p)$ is a disjoint subset of $P(n)$. However, we know that this function doesn't necessarily commute with any map of lists as it needs to send disjoint subsets to subsets. Therefore, the function that sends $x \mapsto x(0) \subseteq x(n)$ is not continuous.
#     \end{itemize}
#
#     Let us now turn to the ``generalization of compactness'' in terms of our notions. Consider the following category:
#
#     \[
#     \begin{tikzcd}
#         A \ar[dr, "\mu"] \ar[rr, "\nu"]&
#         \ar[d, "\epsilon"']\ar[r,"f"']&\ar[d,"g"]\ar[r,"\theta"]&
#         B
#         \ar[d,two heads,"\psi"]\\
#         \ar[r,"\kappa"] &
#         \ar[r,"k"]
#         &
#         \ar[u,"y"]
#         &
#         Z
#         \ar[from=rr,"h"]
#         &
#         \ar[from=dddddd,"z"']
#     \end{tikzcd}
#     \]
#     Firstly, let us make use of the universal property that $g$ sends comparable indices in a monoid to the same index, thus ensuring that the diagram commutes. Using that $h$ sends any $p_1,\dots,p_m$ to either $p_0,\dots,p_1\cup p_2,\dots,p_m$, we get a monoid morphism
#     \[
#     (A \times Y,z,g,k)\times (B \times Z,f,h) \to (A \times X,y,g,k),
#     \]
#     which ensures the commutativity in the diagram. But $k$ does not necessarily correspond to a monoid homomorphism because the function $g$ cannot always be continuous. However, since $\epsilon$ sends all $m$-sorted indices to the initial subset $P(m)$, the $x$ can be a disjoint subset of $P(m)$ such that $(x \times g)(p_0,\dots,p_m,z) = (g(p_0),\dots,g(p_m))$.
#     Moreover, using that $\theta$ sends all $n$-sorted indices to $P(n) \times \{0,1\}$ and $x(p) \subseteq x(n) + n - 1$, we get a monoid morphism
#     \[
#     (A \times Y,z,g,k)\times (B \times Z,f,h)\to (A \times X,y,g,k)
#     \]
#     which is also a continuous monoid morphism because $y$ sends all $m$-sorted indices to $P(m) \times \{0,1\}$ and $g(p_0,\dots,p_m) = h(p_0,\dots,p_m)$.
#
#     Next, recall that $\epsilon$ is constant at the initial point so we can replace the last three counits with identity $0 \to P(m) \times \{0,1\}$ in the first equation. Now it becomes clear that $\theta$ must still be continuous, i.e.\ $f$ is continuous. By the first part of the second part of the fact, we can replace $p_i$ in the equation with $p_i$ in the first equation as well and the proof now works as expected.
# \end{proof}
#
# Recall from \cite{Garner2008} that the natural number sequence
# \[
# P(n) = \{p<q \mid p+q=n\}
# \]
# defines an \textit{index space} if the sequence is terminal or converges to $n$. Hence, given an index set $P$, one can define $\mathbf{D}(P) = \{p<q \mid p+q=n\}$ as the interval $P(n)$. Here we made use of a little notation. The function $\ell: P(n) \to P(n)$ sends $p<q$ to $p+\ell(q)-n$. When the natural number sequence converges, we call $\ell$ the \textit{step length}: for any $p$ and $q$ in $P(n)$, there exists some $n'$ such that $\ell(q)=n'$ and that $p<n'<q$. This is true for $\ell(0)=0$ and $\ell(1)=1$ \cite{Garner2008}, while for $n \geq 3$, the step lengths of \textit{all the elements in $P(n)$} converge to $1$. The sequence $\{p<q \mid p+q=n\}$ converges to $n$ when viewed as a proper number sequence of steps, and hence to $n'$ when viewed as a proper number sequence of indices in a given index space.
#
# The next thing we need is a function of two parameters:
#
# \begin{proposition}[{\cite[Theorem~4.5]{Garner2008}}]\label{prop:mono}
#     If $\mathcal{C}$ is a category with a monoid structure, then there is a unique $R: P(n) \to R_n$ such that, for each index $p < q$ in $P(n)$, there exists some $n'$ such that $n'<p<n'$.
# \end{proposition}
#
# To define the inverse of this property, we first need a notion of ``disjointness'': we call an element of a subset $X$ disjoint if it is either $0$ or $p+q=n$ for some $p<q \in P(n)$.
#
# \begin{definition}
#     Let $X = \{x_0,\dots,x_n\}$ be a finite set, and let $R: P(n) \to R_n$ be a function. The \textit{disjoint filter} on $X$ is denoted $\bigcap_i X(p,q)$ for all $p < q$ in $P(n)$; i.e.\ $\bigcap_i X(p,q)$ is the set of all $x \in X$ such that $x(p)=0$ and $x(q)=n$. Then, if $f: X \to Y$ is a morphism of sets, then $f^\prime: Y \to X$ is called the \textit{inverse} of $f$; and if $f^\prime$ is a monoid homomorphism then $f: X \to Y$ is called the \textit{retraction of $f$} of $f$.
#
#     Note that, as a consequence of Proposition~\ref{prop:mono}, the disjoint filter restricts to a function $R^\prime: P(n) \to X$.
# \end{definition}
#
# This definition of a disjoint filter encodes the fact that the filter sends the complement of every subset to a singleton set, and hence we can replace all disjoint subsets of a large finite set by a single element. This can easily be seen in the following example.
#
# \begin{example}\label{eg:monoid-disjoint-filter}
#     Recall that $P(n) = \{0,1,\ldots,n\}$ is the set of natural numbers. Consider the following diagram for $n=5$:
#
#     \[
#     \begin{tikzcd}
#         0 \ar[r,"f_1",swap] \ar[r,"f_2"] &  1 \ar[r,"f_3"] &  2 \ar[r,"f_4"] \ar[r,"f_5"] &  3 \ar[r,"f_6"] \ar[r,"f_7"] &  4 \ar[r,"f_8"] \ar[r,"f_9"] &  5 \ar[r,"f_10"]
#         \ar[from=r,"f_11" Swap,shift left=0.2cm] &
#         0,
#     \end{tikzcd}
#     \]
#     where $f_i$ is an element of the subset $P(n) \setminus \{1\}$. If we take $R(f_1) = f_6$ and $R(f_2) = f_9$, then $\bigcap_i X(p,q) = \{0,1\} \setminus \{1\}$ which clearly gives the disjoint filter for the diagram. Conversely, if $X=\{x_0,\dots,x_n\}$ is a finite set, then the retraction of $f = \{f_1,\dots,f_n\}$ is the function
#     \[
#     R^\prime(X) := \{x_0,x_1,x_2,\dots,x_n\},
#     \]
#     whose image consists of the elements of $X$ such that $f_i(x_i)=0$ for all $i$.
# \end{example}
#
# The previous examples tell us that we can express the inverse of disjoint filters via a unique function $\ell: P(n) \to R_n$: for any $n \geq 0$ and any $p < q$, we have
# \begin{align*}
#     \ell(p) &= \left\{ k \in R_n(p) \mid p+q=k \right\} \\
#      &= \left\{ k < n' \mid p+q=k \right\} \\
#       &= \left\{ p + n' < q \mid p+q=n' \right\}.
# \end{align*}
# Thus, given a function $R: P(n) \to R_n$ and a disjoint filter $\{x_0,\dots,x_n\}$, we can calculate the number of times $x \in \bigcap_i X(p,q)$ appears in the disjoint filter. To see this for an element $x \in X$, we note that, since $P(n) \setminus \{1\}$ is disjoint, each $p+q=k$ is disjoint by assumption. Thus, we can find $k < n'$ such that $p+q=k$ and $p < n'$. Then, there exists $p+q=k$, as $p$ and $q$ are both disjoint. Thus $x$ appears only once in the filtered union.
#
# \begin{corollary}
#     If $\mathcal{C}$ is a category with a monoid structure, then there is a unique retraction $R^\prime: P(n) \to X$ with $R^\prime(x)=0$ whenever $x\in \bigcap_i X(p,q)$ and $x(p) \subseteq x(q)$.
# \end{corollary}
#
# With these definitions, we can now define a monoid endofunctor on $P$. Our first goal is to understand the case where the domain of the monoid structure is nonempty.  This can be done in two different ways. One way is to define $\mathbf{D}^{*}$ in terms of the disjoint filters, and the other uses the function $R^\prime$ as a \textit{retract of the endofunctor}.
#
# We first define $\mathbf{D}^{*}$ in terms of the disjoint filters and use the function $R^\prime$ as a \textit{retraction of the endofunctor}.
#
# \begin{lemma}
#     If $\mathcal{C}$ is a category with a monoid structure, then $\mathbf{D}^{*}$ is a retraction of the endofunctor $\id_\cat{S} \colon \cat{S} \to \cat{S}$.
# \end{lemma}
#
# \begin{proof}
#     Let $p,q \in P(n)$ and let $R^\prime(x)=0$ whenever $x\in \bigcap_i X(p,q)$ and $x(p) \subseteq x(q)$. So if $\cat{S}$ is the category with objects $x_0,\dots,x_n$, then each $p+q=k$ is disjoint by assumption. Hence, it suffices to verify that each $p \in P(n)$ and $q \in R^\prime(x)$ is disjoint. In this case, $k$ is the smallest natural number such that $p+q=k$, and the statement follows from \ref{prop:mono}.
# \end{proof}
#
# We now use the following lemma and proposition.
#
# \begin{proposition}
#     If $\mathcal{C}$ is a category with a monoid structure, then the monoid endofunctor $\mathbf{D}^{*} \colon P(n) \to \mathbf{D}(P)$ is also a retraction.
# \end{proposition}
#
# \begin{proof}
#     We first describe the definition. We define the composite map
#     \[
#         \mathbf{D}^{*}_n := \{\textstyle\{p<q \mid p+q=n\}\},
#     \]
#     which is the list of all $n$-sorted disjoint subsets of $P(n)$. For $n=0$, we have $\mathbf{D}^{*}_0:= \bigcap_i P(i)$. Then, given an element $(p,q)\in P(n)$, we have $p+q=n$ and hence $\mathbf{D}^{*}_n(p,q)=\{\{p<q \mid p+q=n\}\}$. We then use Lemma~\ref{lemma:monoid-functor-retractions} to construct the composite map
#     \[
#         \mathbf{D}^{*}_n \times \mathbf{D}^{*}_m := P(n \times m),
#     \]
#     which is the product of the function $R^\prime: P(n) \to R_n$ and the function $R^\prime: R_m \to P(n \times m)$ which is the function given by $R^\prime(x)=0$ whenever $x\in \bigcap_i X(p,q)$ and $x(p) \subseteq x(q)$.
#     After composing this composite map with $\mathbf{D}^{*}_n$ we get the final composite map
#     \[
#         \mathbf{D}^{*} \times \mathbf{D}^{*} = P(n),
#     \]
#     which is a retraction of the endofunctor by Lemma~\ref{lemma:monoid-functor-retractions}.
#
#     We can now show the claim. Let $p,q \in P(n)$ and $R^\prime(x)=0$ whenever $x\in \bigcap_i X(p,q)$ and $x(p) \subseteq x(q)$. Suppose that $p+q=n$.
#     For $n=0$, we observe that $p+q=0=n+n$ so there is no change in the monoid structure on $\mathbf{D}^{*}_0$. For any $n \geq 1$, let $r_n(p,q)$ be the number of times $p+q=n$ appears in $R^\prime(x)$, i.e., $p+q=n$. We define $r_n^\prime: P(n) \to R_n$ as the function $\{p<q \mid p+q=n\} \to R_n$ given by $\{p<q \mid p+q=n\}$ is the unique element $(p,q)$ such that $p+q=n$ and $\{p<q \mid p+q=n\} \neq \{p<q \mid p+q=n+n\}$, so it follows that $r_n^\prime(p,q)=0$ unless $p+q=n$. We then compute $r_n^\prime \mathbf{D}^{*}_n \times \mathbf{D}^{*} := r_n^\prime(n,n)+r_n^\prime(n,n)+r_n^\prime(n,n)+\cdots$. That is, each $p \in P(n)$ is composed with $r_n^\prime(p) = 0$.
#
#     Suppose that $p+q=n$. Because $\mathbf{D}^{*}_n$ is a retraction, we have
#     \[
#         \mathbf{D}^{*}_n(p,q)=\{\{p<q \mid p+q=n\}\}.
#     \]
#     If $q=p+n$, then $\{p<q \mid p+q=n\}=P(n)$ and hence $r_n^\prime(p,q)=0$. We conclude that $r_n^\prime(p,q)>0$.
#
#     Suppose that $p \notin P(n)$. By the assumption of disjointness, $p+q=n$ and $q < n'.$ Then, $r_n^\prime(p,q)<0$, i.e.\ $r_n^\prime(p+n',q)>0$ for some $n'+p \in P(n)$. But $p+n' < p+q < n$ so $r_n^\prime(p,q)>0$.
#
#     This completes the proof of the lemma. It remains to prove that $\mathbf{D}^{*} \times \mathbf{D}^{*}:= P(n)$. For each $n \geq 1$ we have
#     \[
#         \mathbf{D}^{*} \times \mathbf{D}^{*} := P(n).
#     \]
# \end{proof}
#
# Next, we show how the endofunctor $\mathbf{D}^{*} \colon P(n) \to \mathbf{D}(P)$ is also retractable.
#
# \begin{lemma}
#     If $\mathcal{C}$ is a category with a monoid structure, then $\mathbf{D}^{*} \colon P(n) \to \mathbf{D}(P)$ is retractable.
# \end{lemma}
#
# \begin{proof}
#     Let $p,q \in P(n)$, and let $R^\prime(x)=0$ whenever $x\in
# \end{document}
#  \bigcap_i X(p,q)$ and $x(p) \subseteq x(q)$. Suppose that $p+q=n$. In this case, it suffices to verify that $p+q=n$ holds for each $n'.
#     Since $\mathbf{D}^{*}$ is a retraction, for $n' \geq 0$, we have $p+q=n'$ and hence $p < n'$ so $r_n^\prime(p,q)=n'.$
#     From this it follows that $r_n^\prime(p+n',q)>0$ and hence $r_n^\prime(p,q)>0$. This completes the proof of the lemma.
# \end{proof}
#
# We now show how the endofunctor $\id_{\cat{S}}$ becomes retractable.
#
# \begin{lemma}\label{lemma:id-endofunctor}
#     If $\cat{S}$ is a category, then $\id_{\cat{S}}$ is a retraction of the endofunctor $\id_{\cat{S}}$.
# \end{lemma}
#
# \begin{proof}
#     We

# %%
output_dir = "/content/drive/MyDrive/fake_papers"
os.makedirs(output_dir, exist_ok=True)

# %%
prefix = [r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{On The Monoindal Endofunctor In Sparse Categories}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{The Sheaffification of Finite Groups}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{Co-Algebras: Why Do They Exist?}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{Functorialization Of Higher Topos And Their Geometry}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{Topological Manifolds: A Categorical Perspective}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{Proof Of the Riemann Hypothesis Using Category Theory}
\author{Max Vazquez}
\maketitle

""",
r"""
\documentclass[a4paper,reqno,oneside]{article}
\pdfoutput=1
\include{mathcommands.extratex}
\begin{document}
\title{Solving Every Open Problem In Math With Category Theory}
\author{Max Vazquez}
\maketitle

"""

]
suffix =r"""
\end{document}
"""

# %%
num_papers = 50  # Number of papers to generate

for i in tqdm(range(1, num_papers + 1), desc="Generating Papers"):
    # Generate the LaTeX content
    paper_content = get_code_completion(prefix[i % len(prefix)], suffix)

    # Define the filename with zero-padding for sorting
    filename = os.path.join(output_dir, f"fake_math_paper_{i:03d}.tex")

    # Save the content to a .tex file
    with open(filename, 'w') as file:
        file.write(paper_content)
# Out:
# Generating Papers:   0%|          | 0/100 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Generating Papers:   1%|          | 1/100 [01:11<1:57:09, 71.00s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
